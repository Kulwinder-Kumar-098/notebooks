# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('bail_corpus.csv')
df
# Out:
#                  id  chunk_index  total_chunks  \
# 0      b18352cc44a4            0            48
# 1      90afd903a4f9            1            48
# 2      57e30cc347a1            2            48
# 3      9b31f15c2d30            3            48
# 4      ed9e5d5ba998            4            48
# ...             ...          ...           ...
# 14213  ccac8ea28e78           75            80
# 14214  bb659c3b16d2           76            80
# 14215  c2a20066f8ac           77            80
# 14216  fadaa4f3b90a           78            80
# 14217  5987ba69916e           79            80
#
#                                               chunk_text  word_count  \
# 0      Andhra HC (Pre-Telangana) Buddhi Kota Subbarao...         341
# 1      The petitioner Buddhikota Subba Rao, party in ...         263
# 2      2. Both the petitions came for common hearing ...         553
# 3      3. Heard the party in person supra and the lea...         887
# ...

# %%
df['date'].unique()
# Out:
# array(['2017-10-13', '2022-02-07', '2021-03-08', '2026-01-27',
#        '2014-07-28', '2020-12-03', '2017-02-16', '2022-07-26',
#        '2023-08-02', '2017-07-27', '2025-04-09', '2022-07-27',
#        '2025-11-28', '2025-10-08', '2025-11-12', '2024-04-09',
#        '2023-02-24', '2024-08-07', '2026-03-10', '2022-03-02',
#        '2021-06-14', '2022-08-31', '2022-03-11', '2022-09-06',
#        '2022-10-18', '2024-08-31', '2026-02-28', '2025-08-12',
#        '2011-11-23', '1994-03-11', '1987-10-20', '2017-01-24',
#        '2021-09-01', '2021-10-06', '2025-10-14', '2012-01-19',
#        '2000-12-13', '2021-07-15', '2015-03-05', '2021-07-29',
#        '2021-08-18', '2025-12-19', '2021-03-15', '2022-04-21',
#        '2021-04-08', '2022-05-25', '2023-12-22', '2022-09-09',
#        '2022-10-07', '2024-02-07', '2024-03-26', '2024-03-25',
#        '2024-03-07', '2024-03-04', '2025-01-28', '2022-12-02',
#        '2023-01-30', '2021-05-28', '2020-05-12', '2021-10-25',
# ...

# %%
df.isnull().sum()
# Out:
# id                0
# chunk_index       0
# total_chunks      0
# chunk_text        0
# word_count        0
# tid               0
# case_name         0
# date              0
# year            132
# court             0
# court_type        0
# judge             0
# cites             0
# cited_by          0
# authority         0
# sections          0
# url               0
# dtype: int64

# %%
df['date'].sort_values(ascending=True)
# Out:
# 6962    1980-04-02
# 6963    1980-04-02
# 4047    1980-04-09
# 4102    1980-04-09
# 4101    1980-04-09
#            ...
# 4513       Unknown
# 4512       Unknown
# 4511       Unknown
# 4482       Unknown
# 4994       Unknown
# Name: date, Length: 14218, dtype: object

# %%
df.groupby(['year']).agg('count')
# Out:
#           id  chunk_index  total_chunks  chunk_text  word_count   tid  \
# year
# 1980.0    77           77            77          77          77    77
# 1985.0   321          321           321         321         321   321
# 1987.0   113          113           113         113         113   113
# 1990.0    37           37            37          37          37    37
# 1992.0    74           74            74          74          74    74
# 1994.0   407          407           407         407         407   407
# 1997.0    53           53            53          53          53    53
# 2000.0    75           75            75          75          75    75
# 2001.0    26           26            26          26          26    26
# 2003.0    19           19            19          19          19    19
# 2004.0    14           14            14          14          14    14
# 2005.0   137          137           137         137         137   137
# ...
